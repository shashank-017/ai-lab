# %% [raw]
# This is for Stop Word Removal for text preprocessing in NLP using nltk

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/shashank017/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

text = "I'm Shashank, and I love to learn NLP! I have just started it and learning tokenizer and stop word removel. It's fantastic to see text preprocessing"

stop_words = set(stopwords.words('english'))
tokens = word_tokenize(text)

filtered_tokens = [word for word in tokens if word.lower() not in stop_words]
filtered_tokens
# Out:
# ["'m",
#  'Shashank',
#  ',',
#  'love',
#  'learn',
#  'NLP',
#  '!',
#  'started',
#  'learning',
#  'tokenizer',
#  'stop',
#  'word',
#  'removel',
#  '.',
#  "'s",
#  'fantastic',
#  'see',
#  'text',
#  'preprocessing']

# %%
text = "Today we will learn about NLP, Please come to the class on time."

stop_words = set(stopwords.words('english'))
token = word_tokenize(text)

filtered_token = [word for word in token if word.lower() not in stop_words]
filtered_token
# Out:
# ['Today', 'learn', 'NLP', ',', 'Please', 'come', 'class', 'time', '.']
