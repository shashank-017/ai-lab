# %%
import nltk
from nltk import FreqDist
from nltk.tokenize import word_tokenize

# %%
text = "this is a sample sentence. the sentence has some common words and some rare words"
words = word_tokenize(text.lower())
freq = FreqDist(words)
filtered_words = [word for word in words if freq[word]>2]
filtered_words
# Out:
# []

# %%
freq
# Out:
# FreqDist({'sentence': 2, 'some': 2, 'words': 2, 'this': 1, 'is': 1, 'a': 1, 'sample': 1, '.': 1, 'the': 1, 'has': 1, ...})

# %%
type(freq)
# Out:
# nltk.probability.FreqDist
