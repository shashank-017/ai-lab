# %% [raw]
# This notebook contains the mechanism for correcting words using NLTK.
# There are two methods of doing this:
#
# 1. Jaccard's distance
# 2. Edit distance

# %% [raw]
# Jaccard's distance

# %%
sent1 = set("It might help to re-install Python if possible")
sent2 = set("It can help to install Python again if possible")
sent3 = set("It can be so helpful to reinstall C++ if possible")
sent4 = set("Help if possible Python to re-install if might")
sent5 = set("I love Python programming")

# %%
import nltk

jd_sent_1_2 = nltk.jaccard_distance(sent1,sent2)
jd_sent_1_3 = nltk.jaccard_distance(sent1,sent3)
jd_sent_1_4 = nltk.jaccard_distance(sent1,sent4)
jd_sent_1_5 = nltk.jaccard_distance(sent1,sent5)

# %%
print(jd_sent_1_2,jd_sent_1_3,jd_sent_1_4,jd_sent_1_5)
# Out:
# 0.19047619047619047 0.375 0.09523809523809523 0.23809523809523808

# %% [raw]
# Edit distance

# %%
w1 = 'mapping'
w2 = 'mappings'
nltk.edit_distance(w1,w2)
# Out:
# 1

# %%
nltk.edit_distance(sent1,sent2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 nltk.edit_distance(sent1,sent2)
#
# File /opt/anaconda3/lib/python3.13/site-packages/nltk/metrics/distance.py:107, in edit_distance(s1, s2, substitution_cost, transpositions)
#     105 last_right_buf = 0
#     106 for j in range(1, len2 + 1):
# --> 107     last_left = last_left_t[s2[j - 1]]
#     108     last_right = last_right_buf
#     109     if s1[i - 1] == s2[j - 1]:
#
# TypeError: 'set' object is not subscriptable
