# %%
pip install spacy #install spacy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 2.0 MB/s  0:00:02 eta 0:00:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 656.7/656.7 kB 7.7 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 788.1/788.1 kB 10.1 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 2.6 MB/s  0:00:00m eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15/15 [spacy]m14/15 [spacy]d]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#downloading a pre-trained model (English)
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 8.3 MB/s  0:00:01m0:00:010:01
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
#import spacy and load the model
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
text = "Spacy is an amazing Python library. Let's study about tokenisation."
doc = nlp(text)
for tokens in doc:
    print(tokens.text)
# Out:
# Spacy
# is
# an
# amazing
# Python
# library
# .
# Let
# 's
# study
# about
# tokenisation
# .
